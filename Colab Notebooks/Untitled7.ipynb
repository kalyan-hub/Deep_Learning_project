# %%
class person():
    def __init__(self,name,branch,marks):
        self.name=name
        self.branch=branch
        self.marks=marks
    def display(self):
        print(self.name,self.branch,self.marks)
p=person("charan","EEE",967)
p.display()
# Out:
# charan EEE 967

# %%
class test():
    num1=100
    num2=200
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
    def display(self):
        print(self.num1,self.num2)
print(test.num1)
print(test.num2)
t=test(1000,2000)
t.display()
# Out:
# 100
# 200
# 1000 2000

# %%
    a=eval(input("enter"))
    s1=set()
    l=[]
    uniq=[ ] 
    for x in a: 
        if x in s1: 
            uniq.append(x) 
        s1.add(x)
    for i in uniq:
      mode=i.count(uniq)
      l.append(mode)
    l=sorted()
    print(l[0])
# Out:
# enter[1,1,1,2,3,4,5,5,5,6]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3eb498592e83> in <module>()
#       8     s1.add(x)
#       9 for i in uniq:
# ---> 10   mode=i.count(uniq)
#      11   l.append(mode)
#      12 l=sorted()
#
# AttributeError: 'int' object has no attribute 'count'

# %%
l=[1,1,2,3,3,4,5,6,7,7,8,8,8]
d={}
for i in l:
  d[i]=d.get(i,0)+1
print(d)
modes = []
maxTimes = max(d,key=d.get)
print("max value: ",maxTimes)
# Out:
# {1: 2, 2: 1, 3: 2, 4: 1, 5: 1, 6: 1, 7: 2, 8: 3}
# max value:  8
