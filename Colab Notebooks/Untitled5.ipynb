# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.6.0+cu101)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Requirement already satisfied: torch==1.5.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0->torchvision) (0.16.0)

# %%
import torch
import torchvision

model = torchvision.models.resnet18(pretrained=True)
model.eval()
example = torch.rand(1, 3, 224, 224)
traced_script_module = torch.jit.trace(model, example)
traced_script_module.save("app/src/main/assets/model.pt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-1e84a167eeac> in <module>()
#       6 example = torch.rand(1, 3, 224, 224)
#       7 traced_script_module = torch.jit.trace(model, example)
# ----> 8 traced_script_module.save("app/src/main/assets/model.pt")
#
# /usr/local/lib/python3.6/dist-packages/torch/jit/__init__.py in save(self, *args, **kwargs)
#    1646             See :func:`torch.jit.save <torch.jit.save>` for details.
#    1647             """
# -> 1648             return self._c.save(*args, **kwargs)
#    1649
#    1650         def _save_for_lite_interpreter(self, *args, **kwargs):
#
# RuntimeError: [enforce fail at inline_container.cc:360] . PytorchStreamWriter failed writing file version: file write failed

# %%
git clone https://github.com/pytorch/android-demo-app.git
cd HelloWorldApp
